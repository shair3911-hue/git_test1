# %% [markdown]
# **# **First Notebook****

# %% [markdown]
# #First Notebook
# This is the first notebook for the project. It contains the initial setup and some basic data exploration.
# ##Importing Libraries
# ```pythonimport pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
# **##Loading the Data**
# ```pythondata = pd.read_csv('data.csv')
# ```##Exploring the Data
# ```pythonprint(data.head())
# print(data.info())
# print(data.describe())
# ```
# *##Visualizing the Data**
# ```pythonplt.figure(figsize=(10,6))
# sns.histplot(data['column_name'], kde=True)
# plt.title('Distribution of Column Name')
# plt.xlabel('Column Name')
# plt.ylabel('Frequency')
# plt.show()
# ```
# ```pythonplt.figure(figsize=(10,6))
# sns.boxplot(x=data['column_name'])
# plt.title('Boxplot of Column Name')
# plt.xlabel('Column Name')
# plt.show()
# ``````pythonplt.figure(figsize=(10,6))
# sns.scatterplot(x=data['column1'], y=data['column2'])
# plt.title('Scatter Plot of Column1 vs Column2')
# plt.xlabel('Column1')
# plt.ylabel('Column2')
# plt.show()
# ```
# ##Conclusion
# In this notebook, we have successfully loaded the data, performed some basic exploratory data analysis, and
# visualized the data using various plots. This sets the foundation for further analysis and modeling in the subsequent notebooks.

# %%
print("hello world")
# Out:
# hello world

# %%
print(1+2)
# Out:
# 3
